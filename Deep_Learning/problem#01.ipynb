# %%
import tensorflow as tf
from tensorflow.keras import layers

# Load and preprocess the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape images to include a channel dimension (required for convolutional layers)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Define the first CNN architecture
model1 = tf.keras.Sequential([
    layers.Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(4, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Define the second CNN architecture
model2 = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(4, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Define the third CNN architecture
model3 = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(8, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the models
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the models
model1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
model2.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
model3.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# Evaluate the models
accuracy1 = model1.evaluate(x_test, y_test)[1]
accuracy2 = model2.evaluate(x_test, y_test)[1]
accuracy3 = model3.evaluate(x_test, y_test)[1]

# Print the model summaries
print("Model 1 Summary:")
model1.summary()

print("Model 2 Summary:")
model2.summary()

print("Model 3 Summary:")
model3.summary()

# Create a comparison table
print("CNN Architectures Comparison:")
print("---------------------------------")
print("Model\t\t\tAccuracy")
print("---------------------------------")
print("Model 1\t\t\t{:.2f}%".format(accuracy1 * 100))
print("Model 2\t\t\t{:.2f}%".format(accuracy2 * 100))
print("Model 3\t\t\t{:.2f}%".format(accuracy3 * 100))
print("---------------------------------")
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.3640 - accuracy: 0.8808 - val_loss: 0.1396 - val_accuracy: 0.9597
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0998 - accuracy: 0.9714 - val_loss: 0.1835 - val_accuracy: 0.9459
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0732 - accuracy: 0.9793 - val_loss: 0.0888 - val_accuracy: 0.9748
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.0769 - val_accuracy: 0.9786
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0504 - accuracy: 0.9855 - val_loss: 0.0655 - val_accuracy: 0.9813
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0445 - accuracy: 0.9871 - val_loss: 0.0992 - val_accuracy: 0.9727
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 0.0584 - val_accuracy: 0.9848
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0350 - accuracy: 0.9894 - val_loss: 0.0572 - val_accuracy: 0.9850
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0302 - accuracy: 0.9908 - val_loss: 0.0613 - val_accuracy: 0.9833
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.0597 - val_accuracy: 0.9846
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.6414 - accuracy: 0.8311 - val_loss: 0.2635 - val_accuracy: 0.9522
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2127 - accuracy: 0.9537 - val_loss: 0.1732 - val_accuracy: 0.9582
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1437 - accuracy: 0.9652 - val_loss: 0.1278 - val_accuracy: 0.9677
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1156 - accuracy: 0.9707 - val_loss: 0.1097 - val_accuracy: 0.9708
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0969 - accuracy: 0.9743 - val_loss: 0.1120 - val_accuracy: 0.9702
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0863 - accuracy: 0.9771 - val_loss: 0.1138 - val_accuracy: 0.9684
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0788 - accuracy: 0.9785 - val_loss: 0.0912 - val_accuracy: 0.9750
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0722 - accuracy: 0.9804 - val_loss: 0.0920 - val_accuracy: 0.9764
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0679 - accuracy: 0.9810 - val_loss: 0.0833 - val_accuracy: 0.9778
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0610 - accuracy: 0.9828 - val_loss: 0.0977 - val_accuracy: 0.9727
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.3347 - accuracy: 0.8976 - val_loss: 0.1004 - val_accuracy: 0.9701
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0807 - accuracy: 0.9755 - val_loss: 0.1536 - val_accuracy: 0.9517
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0606 - accuracy: 0.9817 - val_loss: 0.0672 - val_accuracy: 0.9812
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0503 - accuracy: 0.9848 - val_loss: 0.0545 - val_accuracy: 0.9841
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0436 - accuracy: 0.9861 - val_loss: 0.0551 - val_accuracy: 0.9819
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0397 - accuracy: 0.9875 - val_loss: 0.0470 - val_accuracy: 0.9845
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0353 - accuracy: 0.9890 - val_loss: 0.0438 - val_accuracy: 0.9865
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.0654 - val_accuracy: 0.9815
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0299 - accuracy: 0.9906 - val_loss: 0.0465 - val_accuracy: 0.9857
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.0402 - val_accuracy: 0.9888
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0597 - accuracy: 0.9846
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0977 - accuracy: 0.9727
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0402 - accuracy: 0.9888
# Model 1 Summary:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_51 (Conv2D)          (None, 26, 26, 8)         80
#
#  batch_normalization_47 (Bat  (None, 26, 26, 8)        32
#  chNormalization)
#
#  max_pooling2d_35 (MaxPoolin  (None, 13, 13, 8)        0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 11, 11, 16)        1168
#
#  batch_normalization_48 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 3, 3, 32)          4640
#
#  batch_normalization_49 (Bat  (None, 3, 3, 32)         128
#  chNormalization)
#
#  flatten_18 (Flatten)        (None, 288)               0
#
#  dense_37 (Dense)            (None, 4)                 1156
#
#  dense_38 (Dense)            (None, 10)                50
#
# =================================================================
# Total params: 7,318
# Trainable params: 7,206
# Non-trainable params: 112
# _________________________________________________________________
# Model 2 Summary:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_54 (Conv2D)          (None, 26, 26, 32)        320
#
#  batch_normalization_50 (Bat  (None, 26, 26, 32)       128
#  chNormalization)
#
#  max_pooling2d_37 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 11, 11, 16)        4624
#
#  batch_normalization_51 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_56 (Conv2D)          (None, 3, 3, 8)           1160
#
#  batch_normalization_52 (Bat  (None, 3, 3, 8)          32
#  chNormalization)
#
#  flatten_19 (Flatten)        (None, 72)                0
#
#  dense_39 (Dense)            (None, 4)                 292
#
#  dense_40 (Dense)            (None, 10)                50
#
# =================================================================
# Total params: 6,670
# Trainable params: 6,558
# Non-trainable params: 112
# _________________________________________________________________
# Model 3 Summary:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_57 (Conv2D)          (None, 26, 26, 32)        320
#
#  batch_normalization_53 (Bat  (None, 26, 26, 32)       128
#  chNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 11, 11, 16)        4624
#
#  batch_normalization_54 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_40 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_59 (Conv2D)          (None, 3, 3, 8)           1160
#
#  batch_normalization_55 (Bat  (None, 3, 3, 8)          32
#  chNormalization)
#
#  flatten_20 (Flatten)        (None, 72)                0
#
#  dense_41 (Dense)            (None, 8)                 584
#
#  dense_42 (Dense)            (None, 10)                90
#
# =================================================================
# Total params: 7,002
# Trainable params: 6,890
# Non-trainable params: 112
# _________________________________________________________________
# CNN Architectures Comparison:
# ---------------------------------
# Model			Accuracy
# ---------------------------------
# Model 1			98.46%
# Model 2			97.27%
# Model 3			98.88%
# ---------------------------------

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Load and preprocess the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape images to include a channel dimension (required for convolutional layers)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
# architecture
model1 = tf.keras.Sequential([
    layers.Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(4, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

accuracy = model1.evaluate(x_test, y_test)[1]

print("Model Accuracy{:.2f}%".format(accuracy * 100))
model1.summary()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.4706 - accuracy: 0.8541 - val_loss: 0.1495 - val_accuracy: 0.9594
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1253 - accuracy: 0.9671 - val_loss: 0.1017 - val_accuracy: 0.9708
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0928 - accuracy: 0.9753 - val_loss: 0.0789 - val_accuracy: 0.9797
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0775 - accuracy: 0.9786 - val_loss: 0.0738 - val_accuracy: 0.9805
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0674 - accuracy: 0.9814 - val_loss: 0.0636 - val_accuracy: 0.9823
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0567 - accuracy: 0.9841 - val_loss: 0.0684 - val_accuracy: 0.9805
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0532 - accuracy: 0.9848 - val_loss: 0.0568 - val_accuracy: 0.9839
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0463 - accuracy: 0.9868 - val_loss: 0.0693 - val_accuracy: 0.9792
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0431 - accuracy: 0.9879 - val_loss: 0.0732 - val_accuracy: 0.9792
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 0.0607 - val_accuracy: 0.9827
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0607 - accuracy: 0.9827
# Model Accuracy98.27%
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 26, 26, 8)         80
#
#  batch_normalization_38 (Bat  (None, 26, 26, 8)        32
#  chNormalization)
#
#  max_pooling2d_29 (MaxPoolin  (None, 13, 13, 8)        0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 11, 11, 16)        1168
#
#  batch_normalization_39 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_30 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 3, 3, 32)          4640
#
#  batch_normalization_40 (Bat  (None, 3, 3, 32)         128
#  chNormalization)
#
#  flatten_15 (Flatten)        (None, 288)               0
#
#  dense_31 (Dense)            (None, 4)                 1156
#
#  dense_32 (Dense)            (None, 10)                50
#
# =================================================================
# Total params: 7,318
# Trainable params: 7,206
# Non-trainable params: 112
# _________________________________________________________________

# %%
# architecture
model2 = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(4, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model2.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

accuracy = model1.evaluate(x_test, y_test)[1]

print("Model Accuracy{:.2f}%".format(accuracy * 100))
model2.summary()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.5166 - accuracy: 0.8354 - val_loss: 0.1814 - val_accuracy: 0.9502
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1533 - accuracy: 0.9567 - val_loss: 0.1464 - val_accuracy: 0.9585
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1130 - accuracy: 0.9676 - val_loss: 0.0988 - val_accuracy: 0.9712
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0922 - accuracy: 0.9733 - val_loss: 0.0888 - val_accuracy: 0.9744
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0806 - accuracy: 0.9763 - val_loss: 0.0812 - val_accuracy: 0.9758
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0713 - accuracy: 0.9786 - val_loss: 0.0951 - val_accuracy: 0.9714
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0660 - accuracy: 0.9797 - val_loss: 0.0671 - val_accuracy: 0.9792
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0600 - accuracy: 0.9815 - val_loss: 0.0658 - val_accuracy: 0.9789
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0565 - accuracy: 0.9823 - val_loss: 0.0754 - val_accuracy: 0.9783
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0523 - accuracy: 0.9844 - val_loss: 0.0720 - val_accuracy: 0.9792
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0607 - accuracy: 0.9827
# Model Accuracy98.27%
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 26, 26, 32)        320
#
#  batch_normalization_41 (Bat  (None, 26, 26, 32)       128
#  chNormalization)
#
#  max_pooling2d_31 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 11, 11, 16)        4624
#
#  batch_normalization_42 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_32 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 3, 3, 8)           1160
#
#  batch_normalization_43 (Bat  (None, 3, 3, 8)          32
#  chNormalization)
#
#  flatten_16 (Flatten)        (None, 72)                0
#
#  dense_33 (Dense)            (None, 4)                 292
#
#  dense_34 (Dense)            (None, 10)                50
#
# =================================================================
# Total params: 6,670
# Trainable params: 6,558
# Non-trainable params: 112
# _________________________________________________________________

# %%
# architecture
model3 = tf.keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(8, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model3.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

accuracy = model1.evaluate(x_test, y_test)[1]

print("Model Accuracy{:.2f}%".format(accuracy * 100))
model3.summary()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 5ms/step - loss: 0.3141 - accuracy: 0.9076 - val_loss: 0.1452 - val_accuracy: 0.9525
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0765 - accuracy: 0.9775 - val_loss: 0.0815 - val_accuracy: 0.9751
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0600 - accuracy: 0.9818 - val_loss: 0.0507 - val_accuracy: 0.9845
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0500 - accuracy: 0.9843 - val_loss: 0.0515 - val_accuracy: 0.9843
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0448 - accuracy: 0.9859 - val_loss: 0.0510 - val_accuracy: 0.9835
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0390 - accuracy: 0.9871 - val_loss: 0.0384 - val_accuracy: 0.9875
# Epoch 7/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0351 - accuracy: 0.9886 - val_loss: 0.0433 - val_accuracy: 0.9867
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0331 - accuracy: 0.9897 - val_loss: 0.0503 - val_accuracy: 0.9847
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0291 - accuracy: 0.9906 - val_loss: 0.0405 - val_accuracy: 0.9879
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.0363 - val_accuracy: 0.9886
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0607 - accuracy: 0.9827
# Model Accuracy98.27%
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 26, 26, 32)        320
#
#  batch_normalization_44 (Bat  (None, 26, 26, 32)       128
#  chNormalization)
#
#  max_pooling2d_33 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 11, 11, 16)        4624
#
#  batch_normalization_45 (Bat  (None, 11, 11, 16)       64
#  chNormalization)
#
#  max_pooling2d_34 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 3, 3, 8)           1160
#
#  batch_normalization_46 (Bat  (None, 3, 3, 8)          32
#  chNormalization)
#
#  flatten_17 (Flatten)        (None, 72)                0
#
#  dense_35 (Dense)            (None, 8)                 584
#
#  dense_36 (Dense)            (None, 10)                90
#
# =================================================================
# Total params: 7,002
# Trainable params: 6,890
# Non-trainable params: 112
# _________________________________________________________________
